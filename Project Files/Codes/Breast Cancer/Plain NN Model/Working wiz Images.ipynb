# %%
import h5py
from PIL import Image #It is a preferred image manipulation tool. In Python 3,
# Pillow python library which is nothing but the upgradation of PIL only.
import numpy as np
from numpy import asarray
import matplotlib.pyplot as plt

# %%
print('Installed Pillow Version:', PIL.__version__)
# Out:
# Installed Pillow Version: 5.3.0

# %%
img = Image.open('Back.jpg')
  
# summarize some details about the image
print(img.format)
print(img.size)
print(img.mode)
# Out:
# JPEG
# (1544, 944)
# RGB

# %%
np_img = np.array(img)
print(np_img.shape)

# OR
array_data = asarray(img)
array_data[1,1]
# Out:
# (944, 1544, 3)
# array([25, 33, 36], dtype=uint8)

# %%
# Initializing h5py file

#hp = h5py.File('Images.h5', 'w')

# %%
#hp.create_dataset('Images', data= [array_data])

# %%
#Read file
hp = h5py.File('Images.h5', 'r')

# %%
hp['Images']
# Out:
# <HDF5 dataset "Images": shape (1, 944, 1544, 3), type "|u1">

# %%
plt.imshow(np_img)

# %%
# Resizing Image
new_width  = 128
new_height = 128
img = img.resize((new_width, new_height), Image.ANTIALIAS)
img.save(fp = 'newimage.png')

# %%
img2 = Image.open('newimage.png')
img2.size
# Out:
# (128, 128)

# %%
np_img2 = np.array(img2)
plt.imshow(np_img2)

# %%
img.close()
img2.close()
